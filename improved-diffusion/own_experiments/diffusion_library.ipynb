# %%
! pip install denoising_diffusion_pytorch
# Out:
# Collecting denoising-diffusion-pytorch
#   Downloading denoising_diffusion_pytorch-1.8.9-py3-none-any.whl (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.0/57.0 kB 1.5 MB/s eta 0:00:00
# Collecting accelerate (from denoising-diffusion-pytorch)
#   Downloading accelerate-0.21.0-py3-none-any.whl (244 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.2/244.2 kB 6.4 MB/s eta 0:00:00a 0:00:01
# Collecting einops (from denoising-diffusion-pytorch)
#   Downloading einops-0.6.1-py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 4.5 MB/s eta 0:00:00
# Collecting ema-pytorch (from denoising-diffusion-pytorch)
#   Downloading ema_pytorch-0.2.3-py3-none-any.whl (4.4 kB)
# Requirement already satisfied: numpy in /home/viki/anaconda3/lib/python3.11/site-packages (from denoising-diffusion-pytorch) (1.24.3)
# Requirement already satisfied: pillow in /home/viki/anaconda3/lib/python3.11/site-packages (from denoising-diffusion-pytorch) (9.4.0)
# Collecting pytorch-fid (from denoising-diffusion-pytorch)
#   Downloading pytorch_fid-0.3.0-py3-none-any.whl (15 kB)
# Requirement already satisfied: torch in /home/viki/anaconda3/lib/python3.11/site-packages (from denoising-diffusion-pytorch) (2.0.1)
# Requirement already satisfied: torchvision in /home/viki/anaconda3/lib/python3.11/site-packages (from denoising-diffusion-pytorch) (0.15.2)
# Requirement already satisfied: tqdm in /home/viki/anaconda3/lib/python3.11/site-packages (from denoising-diffusion-pytorch) (4.65.0)
# Requirement already satisfied: packaging>=20.0 in /home/viki/anaconda3/lib/python3.11/site-packages (from accelerate->denoising-diffusion-pytorch) (23.0)
# Requirement already satisfied: psutil in /home/viki/anaconda3/lib/python3.11/site-packages (from accelerate->denoising-diffusion-pytorch) (5.9.0)
# Requirement already satisfied: pyyaml in /home/viki/anaconda3/lib/python3.11/site-packages (from accelerate->denoising-diffusion-pytorch) (6.0)
# Requirement already satisfied: filelock in /home/viki/anaconda3/lib/python3.11/site-packages (from torch->denoising-diffusion-pytorch) (3.9.0)
# Requirement already satisfied: typing-extensions in /home/viki/anaconda3/lib/python3.11/site-packages (from torch->denoising-diffusion-pytorch) (4.6.3)
# Requirement already satisfied: sympy in /home/viki/anaconda3/lib/python3.11/site-packages (from torch->denoising-diffusion-pytorch) (1.11.1)
# Requirement already satisfied: networkx in /home/viki/anaconda3/lib/python3.11/site-packages (from torch->denoising-diffusion-pytorch) (2.8.4)
# Requirement already satisfied: jinja2 in /home/viki/anaconda3/lib/python3.11/site-packages (from torch->denoising-diffusion-pytorch) (3.1.2)
# Requirement already satisfied: scipy in /home/viki/anaconda3/lib/python3.11/site-packages (from pytorch-fid->denoising-diffusion-pytorch) (1.10.1)
# Requirement already satisfied: requests in /home/viki/anaconda3/lib/python3.11/site-packages (from torchvision->denoising-diffusion-pytorch) (2.29.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/viki/anaconda3/lib/python3.11/site-packages (from jinja2->torch->denoising-diffusion-pytorch) (2.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/viki/anaconda3/lib/python3.11/site-packages (from requests->torchvision->denoising-diffusion-pytorch) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/viki/anaconda3/lib/python3.11/site-packages (from requests->torchvision->denoising-diffusion-pytorch) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/viki/anaconda3/lib/python3.11/site-packages (from requests->torchvision->denoising-diffusion-pytorch) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /home/viki/anaconda3/lib/python3.11/site-packages (from requests->torchvision->denoising-diffusion-pytorch) (2023.5.7)
# Requirement already satisfied: mpmath>=0.19 in /home/viki/anaconda3/lib/python3.11/site-packages (from sympy->torch->denoising-diffusion-pytorch) (1.2.1)
# Installing collected packages: einops, ema-pytorch, accelerate, pytorch-fid, denoising-diffusion-pytorch
# Successfully installed accelerate-0.21.0 denoising-diffusion-pytorch-1.8.9 einops-0.6.1 ema-pytorch-0.2.3 pytorch-fid-0.3.0

# %%
! pip install torch-summary
# Out:
# Collecting torch-summary
#   Downloading torch_summary-1.4.5-py3-none-any.whl (16 kB)
# Installing collected packages: torch-summary
# Successfully installed torch-summary-1.4.5

# %%
from denoising_diffusion_pytorch import Unet, GaussianDiffusion, Trainer

model = Unet(
    dim = 64,
    dim_mults = (1, 2, 4, 8),
    flash_attn = True
)

diffusion = GaussianDiffusion(
    model,
    image_size = 128,
    timesteps = 1000,           # number of steps
    sampling_timesteps = 250    # number of sampling timesteps (using ddim for faster inference [see citation for ddim paper])
)
# Out:
# /home/viki/anaconda3/lib/python3.11/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: 'libc10_cuda.so: cannot open shared object file: No such file or directory'If you don't plan on using image functionality from `torchvision.io`, you can ignore this warning. Otherwise, there might be something wrong with your environment. Did you have `libjpeg` or `libpng` installed before building `torchvision` from source?
#   warn(

# %%
from torchsummary import summary
import torch

training_images = torch.rand(8, 3, 128, 128)

for m in diffusion.modules():
    print(m)
# Out:
# GaussianDiffusion(
#   (model): Unet(
#     (init_conv): Conv2d(3, 64, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3))
#     (time_mlp): Sequential(
#       (0): SinusoidalPosEmb()
#       (1): Linear(in_features=64, out_features=256, bias=True)
#       (2): GELU(approximate='none')
#       (3): Linear(in_features=256, out_features=256, bias=True)
#     )
#     (downs): ModuleList(
#       (0): ModuleList(
#         (0-1): 2 x ResnetBlock(
#           (mlp): Sequential(
#             (0): SiLU()
#             (1): Linear(in_features=256, out_features=128, bias=True)
#           )
#           (block1): Block(
#             (proj): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#             (act): SiLU()
#           )
#           (block2): Block(
#             (proj): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#             (act): SiLU()
#           )
#           (res_conv): Identity()
#         )
#         (2): LinearAttention(
#           (norm): RMSNorm()
#           (to_qkv): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (to_out): Sequential(
#             (0): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#             (1): RMSNorm()
#           )
#         )
#         (3): Sequential(
#           (0): Rearrange('b c (h p1) (w p2) -> b (c p1 p2) h w', p1=2, p2=2)
#           (1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1))
#         )
#       )
#       (1): ModuleList(
#         (0-1): 2 x ResnetBlock(
#           (mlp): Sequential(
#             (0): SiLU()
#             (1): Linear(in_features=256, out_features=128, bias=True)
#           )
#           (block1): Block(
#             (proj): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#             (act): SiLU()
#           )
#           (block2): Block(
#             (proj): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#             (act): SiLU()
#           )
#           (res_conv): Identity()
#         )
#         (2): LinearAttention(
#           (norm): RMSNorm()
#           (to_qkv): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (to_out): Sequential(
#             (0): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#             (1): RMSNorm()
#           )
#         )
#         (3): Sequential(
#           (0): Rearrange('b c (h p1) (w p2) -> b (c p1 p2) h w', p1=2, p2=2)
#           (1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#         )
#       )
#       (2): ModuleList(
#         (0-1): 2 x ResnetBlock(
#           (mlp): Sequential(
#             (0): SiLU()
#             (1): Linear(in_features=256, out_features=256, bias=True)
#           )
#           (block1): Block(
#             (proj): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (norm): GroupNorm(8, 128, eps=1e-05, affine=True)
#             (act): SiLU()
#           )
#           (block2): Block(
#             (proj): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (norm): GroupNorm(8, 128, eps=1e-05, affine=True)
#             (act): SiLU()
#           )
#           (res_conv): Identity()
#         )
#         (2): LinearAttention(
#           (norm): RMSNorm()
#           (to_qkv): Conv2d(128, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (to_out): Sequential(
#             (0): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#             (1): RMSNorm()
#           )
#         )
#         (3): Sequential(
#           (0): Rearrange('b c (h p1) (w p2) -> b (c p1 p2) h w', p1=2, p2=2)
#           (1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#         )
#       )
#       (3): ModuleList(
#         (0-1): 2 x ResnetBlock(
#           (mlp): Sequential(
#             (0): SiLU()
#             (1): Linear(in_features=256, out_features=512, bias=True)
#           )
#           (block1): Block(
#             (proj): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (norm): GroupNorm(8, 256, eps=1e-05, affine=True)
#             (act): SiLU()
#           )
#           (block2): Block(
#             (proj): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (norm): GroupNorm(8, 256, eps=1e-05, affine=True)
#             (act): SiLU()
#           )
#           (res_conv): Identity()
#         )
#         (2): Attention(
#           (norm): RMSNorm()
#           (attend): Attend(
#             (attn_dropout): Dropout(p=0.0, inplace=False)
#           )
#           (to_qkv): Conv2d(256, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (to_out): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (3): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#     )
#     (ups): ModuleList(
#       (0): ModuleList(
#         (0-1): 2 x ResnetBlock(
#           (mlp): Sequential(
#             (0): SiLU()
#             (1): Linear(in_features=256, out_features=1024, bias=True)
#           )
#           (block1): Block(
#             (proj): Conv2d(768, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (norm): GroupNorm(8, 512, eps=1e-05, affine=True)
#             (act): SiLU()
#           )
#           (block2): Block(
#             (proj): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (norm): GroupNorm(8, 512, eps=1e-05, affine=True)
#             (act): SiLU()
#           )
#           (res_conv): Conv2d(768, 512, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (2): Attention(
#           (norm): RMSNorm()
#           (attend): Attend(
#             (attn_dropout): Dropout(p=0.0, inplace=False)
#           )
#           (to_qkv): Conv2d(512, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (to_out): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (3): Sequential(
#           (0): Upsample(scale_factor=2.0, mode='nearest')
#           (1): Conv2d(512, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       (1): ModuleList(
#         (0-1): 2 x ResnetBlock(
#           (mlp): Sequential(
#             (0): SiLU()
#             (1): Linear(in_features=256, out_features=512, bias=True)
#           )
#           (block1): Block(
#             (proj): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (norm): GroupNorm(8, 256, eps=1e-05, affine=True)
#             (act): SiLU()
#           )
#           (block2): Block(
#             (proj): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (norm): GroupNorm(8, 256, eps=1e-05, affine=True)
#             (act): SiLU()
#           )
#           (res_conv): Conv2d(384, 256, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (2): LinearAttention(
#           (norm): RMSNorm()
#           (to_qkv): Conv2d(256, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (to_out): Sequential(
#             (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1))
#             (1): RMSNorm()
#           )
#         )
#         (3): Sequential(
#           (0): Upsample(scale_factor=2.0, mode='nearest')
#           (1): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       (2): ModuleList(
#         (0-1): 2 x ResnetBlock(
#           (mlp): Sequential(
#             (0): SiLU()
#             (1): Linear(in_features=256, out_features=256, bias=True)
#           )
#           (block1): Block(
#             (proj): Conv2d(192, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (norm): GroupNorm(8, 128, eps=1e-05, affine=True)
#             (act): SiLU()
#           )
#           (block2): Block(
#             (proj): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (norm): GroupNorm(8, 128, eps=1e-05, affine=True)
#             (act): SiLU()
#           )
#           (res_conv): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (2): LinearAttention(
#           (norm): RMSNorm()
#           (to_qkv): Conv2d(128, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (to_out): Sequential(
#             (0): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#             (1): RMSNorm()
#           )
#         )
#         (3): Sequential(
#           (0): Upsample(scale_factor=2.0, mode='nearest')
#           (1): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       (3): ModuleList(
#         (0-1): 2 x ResnetBlock(
#           (mlp): Sequential(
#             (0): SiLU()
#             (1): Linear(in_features=256, out_features=128, bias=True)
#           )
#           (block1): Block(
#             (proj): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#             (act): SiLU()
#           )
#           (block2): Block(
#             (proj): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#             (act): SiLU()
#           )
#           (res_conv): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (2): LinearAttention(
#           (norm): RMSNorm()
#           (to_qkv): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (to_out): Sequential(
#             (0): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#             (1): RMSNorm()
#           )
#         )
#         (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#     )
#     (mid_block1): ResnetBlock(
#       (mlp): Sequential(
#         (0): SiLU()
#         (1): Linear(in_features=256, out_features=1024, bias=True)
#       )
#       (block1): Block(
#         (proj): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm): GroupNorm(8, 512, eps=1e-05, affine=True)
#         (act): SiLU()
#       )
#       (block2): Block(
#         (proj): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm): GroupNorm(8, 512, eps=1e-05, affine=True)
#         (act): SiLU()
#       )
#       (res_conv): Identity()
#     )
#     (mid_attn): Attention(
#       (norm): RMSNorm()
#       (attend): Attend(
#         (attn_dropout): Dropout(p=0.0, inplace=False)
#       )
#       (to_qkv): Conv2d(512, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (to_out): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (mid_block2): ResnetBlock(
#       (mlp): Sequential(
#         (0): SiLU()
#         (1): Linear(in_features=256, out_features=1024, bias=True)
#       )
#       (block1): Block(
#         (proj): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm): GroupNorm(8, 512, eps=1e-05, affine=True)
#         (act): SiLU()
#       )
#       (block2): Block(
#         (proj): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm): GroupNorm(8, 512, eps=1e-05, affine=True)
#         (act): SiLU()
#       )
#       (res_conv): Identity()
#     )
#     (final_res_block): ResnetBlock(
#       (mlp): Sequential(
#         (0): SiLU()
#         (1): Linear(in_features=256, out_features=128, bias=True)
#       )
#       (block1): Block(
#         (proj): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (act): SiLU()
#       )
#       (block2): Block(
#         (proj): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (act): SiLU()
#       )
#       (res_conv): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (final_conv): Conv2d(64, 3, kernel_size=(1, 1), stride=(1, 1))
#   )
# )
# Unet(
#   (init_conv): Conv2d(3, 64, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3))
#   (time_mlp): Sequential(
#     (0): SinusoidalPosEmb()
#     (1): Linear(in_features=64, out_features=256, bias=True)
#     (2): GELU(approximate='none')
#     (3): Linear(in_features=256, out_features=256, bias=True)
#   )
#   (downs): ModuleList(
#     (0): ModuleList(
#       (0-1): 2 x ResnetBlock(
#         (mlp): Sequential(
#           (0): SiLU()
#           (1): Linear(in_features=256, out_features=128, bias=True)
#         )
#         (block1): Block(
#           (proj): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#           (act): SiLU()
#         )
#         (block2): Block(
#           (proj): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#           (act): SiLU()
#         )
#         (res_conv): Identity()
#       )
#       (2): LinearAttention(
#         (norm): RMSNorm()
#         (to_qkv): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (to_out): Sequential(
#           (0): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#           (1): RMSNorm()
#         )
#       )
#       (3): Sequential(
#         (0): Rearrange('b c (h p1) (w p2) -> b (c p1 p2) h w', p1=2, p2=2)
#         (1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1))
#       )
#     )
#     (1): ModuleList(
#       (0-1): 2 x ResnetBlock(
#         (mlp): Sequential(
#           (0): SiLU()
#           (1): Linear(in_features=256, out_features=128, bias=True)
#         )
#         (block1): Block(
#           (proj): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#           (act): SiLU()
#         )
#         (block2): Block(
#           (proj): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#           (act): SiLU()
#         )
#         (res_conv): Identity()
#       )
#       (2): LinearAttention(
#         (norm): RMSNorm()
#         (to_qkv): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (to_out): Sequential(
#           (0): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#           (1): RMSNorm()
#         )
#       )
#       (3): Sequential(
#         (0): Rearrange('b c (h p1) (w p2) -> b (c p1 p2) h w', p1=2, p2=2)
#         (1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#       )
#     )
#     (2): ModuleList(
#       (0-1): 2 x ResnetBlock(
#         (mlp): Sequential(
#           (0): SiLU()
#           (1): Linear(in_features=256, out_features=256, bias=True)
#         )
#         (block1): Block(
#           (proj): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (norm): GroupNorm(8, 128, eps=1e-05, affine=True)
#           (act): SiLU()
#         )
#         (block2): Block(
#           (proj): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (norm): GroupNorm(8, 128, eps=1e-05, affine=True)
#           (act): SiLU()
#         )
#         (res_conv): Identity()
#       )
#       (2): LinearAttention(
#         (norm): RMSNorm()
#         (to_qkv): Conv2d(128, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (to_out): Sequential(
#           (0): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#           (1): RMSNorm()
#         )
#       )
#       (3): Sequential(
#         (0): Rearrange('b c (h p1) (w p2) -> b (c p1 p2) h w', p1=2, p2=2)
#         (1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#       )
#     )
#     (3): ModuleList(
#       (0-1): 2 x ResnetBlock(
#         (mlp): Sequential(
#           (0): SiLU()
#           (1): Linear(in_features=256, out_features=512, bias=True)
#         )
#         (block1): Block(
#           (proj): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (norm): GroupNorm(8, 256, eps=1e-05, affine=True)
#           (act): SiLU()
#         )
#         (block2): Block(
#           (proj): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (norm): GroupNorm(8, 256, eps=1e-05, affine=True)
#           (act): SiLU()
#         )
#         (res_conv): Identity()
#       )
#       (2): Attention(
#         (norm): RMSNorm()
#         (attend): Attend(
#           (attn_dropout): Dropout(p=0.0, inplace=False)
#         )
#         (to_qkv): Conv2d(256, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (to_out): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (3): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#   )
#   (ups): ModuleList(
#     (0): ModuleList(
#       (0-1): 2 x ResnetBlock(
#         (mlp): Sequential(
#           (0): SiLU()
#           (1): Linear(in_features=256, out_features=1024, bias=True)
#         )
#         (block1): Block(
#           (proj): Conv2d(768, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (norm): GroupNorm(8, 512, eps=1e-05, affine=True)
#           (act): SiLU()
#         )
#         (block2): Block(
#           (proj): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (norm): GroupNorm(8, 512, eps=1e-05, affine=True)
#           (act): SiLU()
#         )
#         (res_conv): Conv2d(768, 512, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (2): Attention(
#         (norm): RMSNorm()
#         (attend): Attend(
#           (attn_dropout): Dropout(p=0.0, inplace=False)
#         )
#         (to_qkv): Conv2d(512, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (to_out): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (3): Sequential(
#         (0): Upsample(scale_factor=2.0, mode='nearest')
#         (1): Conv2d(512, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#     )
#     (1): ModuleList(
#       (0-1): 2 x ResnetBlock(
#         (mlp): Sequential(
#           (0): SiLU()
#           (1): Linear(in_features=256, out_features=512, bias=True)
#         )
#         (block1): Block(
#           (proj): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (norm): GroupNorm(8, 256, eps=1e-05, affine=True)
#           (act): SiLU()
#         )
#         (block2): Block(
#           (proj): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (norm): GroupNorm(8, 256, eps=1e-05, affine=True)
#           (act): SiLU()
#         )
#         (res_conv): Conv2d(384, 256, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (2): LinearAttention(
#         (norm): RMSNorm()
#         (to_qkv): Conv2d(256, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (to_out): Sequential(
#           (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1))
#           (1): RMSNorm()
#         )
#       )
#       (3): Sequential(
#         (0): Upsample(scale_factor=2.0, mode='nearest')
#         (1): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#     )
#     (2): ModuleList(
#       (0-1): 2 x ResnetBlock(
#         (mlp): Sequential(
#           (0): SiLU()
#           (1): Linear(in_features=256, out_features=256, bias=True)
#         )
#         (block1): Block(
#           (proj): Conv2d(192, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (norm): GroupNorm(8, 128, eps=1e-05, affine=True)
#           (act): SiLU()
#         )
#         (block2): Block(
#           (proj): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (norm): GroupNorm(8, 128, eps=1e-05, affine=True)
#           (act): SiLU()
#         )
#         (res_conv): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (2): LinearAttention(
#         (norm): RMSNorm()
#         (to_qkv): Conv2d(128, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (to_out): Sequential(
#           (0): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#           (1): RMSNorm()
#         )
#       )
#       (3): Sequential(
#         (0): Upsample(scale_factor=2.0, mode='nearest')
#         (1): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#     )
#     (3): ModuleList(
#       (0-1): 2 x ResnetBlock(
#         (mlp): Sequential(
#           (0): SiLU()
#           (1): Linear(in_features=256, out_features=128, bias=True)
#         )
#         (block1): Block(
#           (proj): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#           (act): SiLU()
#         )
#         (block2): Block(
#           (proj): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#           (act): SiLU()
#         )
#         (res_conv): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (2): LinearAttention(
#         (norm): RMSNorm()
#         (to_qkv): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (to_out): Sequential(
#           (0): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#           (1): RMSNorm()
#         )
#       )
#       (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#   )
#   (mid_block1): ResnetBlock(
#     (mlp): Sequential(
#       (0): SiLU()
#       (1): Linear(in_features=256, out_features=1024, bias=True)
#     )
#     (block1): Block(
#       (proj): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (norm): GroupNorm(8, 512, eps=1e-05, affine=True)
#       (act): SiLU()
#     )
#     (block2): Block(
#       (proj): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (norm): GroupNorm(8, 512, eps=1e-05, affine=True)
#       (act): SiLU()
#     )
#     (res_conv): Identity()
#   )
#   (mid_attn): Attention(
#     (norm): RMSNorm()
#     (attend): Attend(
#       (attn_dropout): Dropout(p=0.0, inplace=False)
#     )
#     (to_qkv): Conv2d(512, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (to_out): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1))
#   )
#   (mid_block2): ResnetBlock(
#     (mlp): Sequential(
#       (0): SiLU()
#       (1): Linear(in_features=256, out_features=1024, bias=True)
#     )
#     (block1): Block(
#       (proj): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (norm): GroupNorm(8, 512, eps=1e-05, affine=True)
#       (act): SiLU()
#     )
#     (block2): Block(
#       (proj): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (norm): GroupNorm(8, 512, eps=1e-05, affine=True)
#       (act): SiLU()
#     )
#     (res_conv): Identity()
#   )
#   (final_res_block): ResnetBlock(
#     (mlp): Sequential(
#       (0): SiLU()
#       (1): Linear(in_features=256, out_features=128, bias=True)
#     )
#     (block1): Block(
#       (proj): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#       (act): SiLU()
#     )
#     (block2): Block(
#       (proj): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#       (act): SiLU()
#     )
#     (res_conv): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#   )
#   (final_conv): Conv2d(64, 3, kernel_size=(1, 1), stride=(1, 1))
# )
# Conv2d(3, 64, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3))
# Sequential(
#   (0): SinusoidalPosEmb()
#   (1): Linear(in_features=64, out_features=256, bias=True)
#   (2): GELU(approximate='none')
#   (3): Linear(in_features=256, out_features=256, bias=True)
# )
# SinusoidalPosEmb()
# Linear(in_features=64, out_features=256, bias=True)
# GELU(approximate='none')
# Linear(in_features=256, out_features=256, bias=True)
# ModuleList(
#   (0): ModuleList(
#     (0-1): 2 x ResnetBlock(
#       (mlp): Sequential(
#         (0): SiLU()
#         (1): Linear(in_features=256, out_features=128, bias=True)
#       )
#       (block1): Block(
#         (proj): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (act): SiLU()
#       )
#       (block2): Block(
#         (proj): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (act): SiLU()
#       )
#       (res_conv): Identity()
#     )
#     (2): LinearAttention(
#       (norm): RMSNorm()
#       (to_qkv): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (to_out): Sequential(
#         (0): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#         (1): RMSNorm()
#       )
#     )
#     (3): Sequential(
#       (0): Rearrange('b c (h p1) (w p2) -> b (c p1 p2) h w', p1=2, p2=2)
#       (1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1))
#     )
#   )
#   (1): ModuleList(
#     (0-1): 2 x ResnetBlock(
#       (mlp): Sequential(
#         (0): SiLU()
#         (1): Linear(in_features=256, out_features=128, bias=True)
#       )
#       (block1): Block(
#         (proj): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (act): SiLU()
#       )
#       (block2): Block(
#         (proj): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (act): SiLU()
#       )
#       (res_conv): Identity()
#     )
#     (2): LinearAttention(
#       (norm): RMSNorm()
#       (to_qkv): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (to_out): Sequential(
#         (0): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#         (1): RMSNorm()
#       )
#     )
#     (3): Sequential(
#       (0): Rearrange('b c (h p1) (w p2) -> b (c p1 p2) h w', p1=2, p2=2)
#       (1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#     )
#   )
#   (2): ModuleList(
#     (0-1): 2 x ResnetBlock(
#       (mlp): Sequential(
#         (0): SiLU()
#         (1): Linear(in_features=256, out_features=256, bias=True)
#       )
#       (block1): Block(
#         (proj): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm): GroupNorm(8, 128, eps=1e-05, affine=True)
#         (act): SiLU()
#       )
#       (block2): Block(
#         (proj): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm): GroupNorm(8, 128, eps=1e-05, affine=True)
#         (act): SiLU()
#       )
#       (res_conv): Identity()
#     )
#     (2): LinearAttention(
#       (norm): RMSNorm()
#       (to_qkv): Conv2d(128, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (to_out): Sequential(
#         (0): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#         (1): RMSNorm()
#       )
#     )
#     (3): Sequential(
#       (0): Rearrange('b c (h p1) (w p2) -> b (c p1 p2) h w', p1=2, p2=2)
#       (1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#     )
#   )
#   (3): ModuleList(
#     (0-1): 2 x ResnetBlock(
#       (mlp): Sequential(
#         (0): SiLU()
#         (1): Linear(in_features=256, out_features=512, bias=True)
#       )
#       (block1): Block(
#         (proj): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm): GroupNorm(8, 256, eps=1e-05, affine=True)
#         (act): SiLU()
#       )
#       (block2): Block(
#         (proj): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm): GroupNorm(8, 256, eps=1e-05, affine=True)
#         (act): SiLU()
#       )
#       (res_conv): Identity()
#     )
#     (2): Attention(
#       (norm): RMSNorm()
#       (attend): Attend(
#         (attn_dropout): Dropout(p=0.0, inplace=False)
#       )
#       (to_qkv): Conv2d(256, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (to_out): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (3): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   )
# )
# ModuleList(
#   (0-1): 2 x ResnetBlock(
#     (mlp): Sequential(
#       (0): SiLU()
#       (1): Linear(in_features=256, out_features=128, bias=True)
#     )
#     (block1): Block(
#       (proj): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#       (act): SiLU()
#     )
#     (block2): Block(
#       (proj): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#       (act): SiLU()
#     )
#     (res_conv): Identity()
#   )
#   (2): LinearAttention(
#     (norm): RMSNorm()
#     (to_qkv): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (to_out): Sequential(
#       (0): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#       (1): RMSNorm()
#     )
#   )
#   (3): Sequential(
#     (0): Rearrange('b c (h p1) (w p2) -> b (c p1 p2) h w', p1=2, p2=2)
#     (1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1))
#   )
# )
# ResnetBlock(
#   (mlp): Sequential(
#     (0): SiLU()
#     (1): Linear(in_features=256, out_features=128, bias=True)
#   )
#   (block1): Block(
#     (proj): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#     (act): SiLU()
#   )
#   (block2): Block(
#     (proj): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#     (act): SiLU()
#   )
#   (res_conv): Identity()
# )
# Sequential(
#   (0): SiLU()
#   (1): Linear(in_features=256, out_features=128, bias=True)
# )
# SiLU()
# Linear(in_features=256, out_features=128, bias=True)
# Block(
#   (proj): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#   (act): SiLU()
# )
# Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# GroupNorm(8, 64, eps=1e-05, affine=True)
# SiLU()
# Block(
#   (proj): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#   (act): SiLU()
# )
# Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# GroupNorm(8, 64, eps=1e-05, affine=True)
# SiLU()
# Identity()
# ResnetBlock(
#   (mlp): Sequential(
#     (0): SiLU()
#     (1): Linear(in_features=256, out_features=128, bias=True)
#   )
#   (block1): Block(
#     (proj): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#     (act): SiLU()
#   )
#   (block2): Block(
#     (proj): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#     (act): SiLU()
#   )
#   (res_conv): Identity()
# )
# Sequential(
#   (0): SiLU()
#   (1): Linear(in_features=256, out_features=128, bias=True)
# )
# SiLU()
# Linear(in_features=256, out_features=128, bias=True)
# Block(
#   (proj): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#   (act): SiLU()
# )
# Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# GroupNorm(8, 64, eps=1e-05, affine=True)
# SiLU()
# Block(
#   (proj): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#   (act): SiLU()
# )
# Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# GroupNorm(8, 64, eps=1e-05, affine=True)
# SiLU()
# Identity()
# LinearAttention(
#   (norm): RMSNorm()
#   (to_qkv): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (to_out): Sequential(
#     (0): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#     (1): RMSNorm()
#   )
# )
# RMSNorm()
# Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
# Sequential(
#   (0): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#   (1): RMSNorm()
# )
# Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
# RMSNorm()
# Sequential(
#   (0): Rearrange('b c (h p1) (w p2) -> b (c p1 p2) h w', p1=2, p2=2)
#   (1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1))
# )
# Rearrange('b c (h p1) (w p2) -> b (c p1 p2) h w', p1=2, p2=2)
# Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1))
# ModuleList(
#   (0-1): 2 x ResnetBlock(
#     (mlp): Sequential(
#       (0): SiLU()
#       (1): Linear(in_features=256, out_features=128, bias=True)
#     )
#     (block1): Block(
#       (proj): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#       (act): SiLU()
#     )
#     (block2): Block(
#       (proj): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#       (act): SiLU()
#     )
#     (res_conv): Identity()
#   )
#   (2): LinearAttention(
#     (norm): RMSNorm()
#     (to_qkv): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (to_out): Sequential(
#       (0): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#       (1): RMSNorm()
#     )
#   )
#   (3): Sequential(
#     (0): Rearrange('b c (h p1) (w p2) -> b (c p1 p2) h w', p1=2, p2=2)
#     (1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#   )
# )
# ResnetBlock(
#   (mlp): Sequential(
#     (0): SiLU()
#     (1): Linear(in_features=256, out_features=128, bias=True)
#   )
#   (block1): Block(
#     (proj): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#     (act): SiLU()
#   )
#   (block2): Block(
#     (proj): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#     (act): SiLU()
#   )
#   (res_conv): Identity()
# )
# Sequential(
#   (0): SiLU()
#   (1): Linear(in_features=256, out_features=128, bias=True)
# )
# SiLU()
# Linear(in_features=256, out_features=128, bias=True)
# Block(
#   (proj): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#   (act): SiLU()
# )
# Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# GroupNorm(8, 64, eps=1e-05, affine=True)
# SiLU()
# Block(
#   (proj): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#   (act): SiLU()
# )
# Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# GroupNorm(8, 64, eps=1e-05, affine=True)
# SiLU()
# Identity()
# ResnetBlock(
#   (mlp): Sequential(
#     (0): SiLU()
#     (1): Linear(in_features=256, out_features=128, bias=True)
#   )
#   (block1): Block(
#     (proj): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#     (act): SiLU()
#   )
#   (block2): Block(
#     (proj): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#     (act): SiLU()
#   )
#   (res_conv): Identity()
# )
# Sequential(
#   (0): SiLU()
#   (1): Linear(in_features=256, out_features=128, bias=True)
# )
# SiLU()
# Linear(in_features=256, out_features=128, bias=True)
# Block(
#   (proj): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#   (act): SiLU()
# )
# Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# GroupNorm(8, 64, eps=1e-05, affine=True)
# SiLU()
# Block(
#   (proj): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#   (act): SiLU()
# )
# Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# GroupNorm(8, 64, eps=1e-05, affine=True)
# SiLU()
# Identity()
# LinearAttention(
#   (norm): RMSNorm()
#   (to_qkv): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (to_out): Sequential(
#     (0): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#     (1): RMSNorm()
#   )
# )
# RMSNorm()
# Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
# Sequential(
#   (0): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#   (1): RMSNorm()
# )
# Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
# RMSNorm()
# Sequential(
#   (0): Rearrange('b c (h p1) (w p2) -> b (c p1 p2) h w', p1=2, p2=2)
#   (1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
# )
# Rearrange('b c (h p1) (w p2) -> b (c p1 p2) h w', p1=2, p2=2)
# Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
# ModuleList(
#   (0-1): 2 x ResnetBlock(
#     (mlp): Sequential(
#       (0): SiLU()
#       (1): Linear(in_features=256, out_features=256, bias=True)
#     )
#     (block1): Block(
#       (proj): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (norm): GroupNorm(8, 128, eps=1e-05, affine=True)
#       (act): SiLU()
#     )
#     (block2): Block(
#       (proj): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (norm): GroupNorm(8, 128, eps=1e-05, affine=True)
#       (act): SiLU()
#     )
#     (res_conv): Identity()
#   )
#   (2): LinearAttention(
#     (norm): RMSNorm()
#     (to_qkv): Conv2d(128, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (to_out): Sequential(
#       (0): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#       (1): RMSNorm()
#     )
#   )
#   (3): Sequential(
#     (0): Rearrange('b c (h p1) (w p2) -> b (c p1 p2) h w', p1=2, p2=2)
#     (1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#   )
# )
# ResnetBlock(
#   (mlp): Sequential(
#     (0): SiLU()
#     (1): Linear(in_features=256, out_features=256, bias=True)
#   )
#   (block1): Block(
#     (proj): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (norm): GroupNorm(8, 128, eps=1e-05, affine=True)
#     (act): SiLU()
#   )
#   (block2): Block(
#     (proj): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (norm): GroupNorm(8, 128, eps=1e-05, affine=True)
#     (act): SiLU()
#   )
#   (res_conv): Identity()
# )
# Sequential(
#   (0): SiLU()
#   (1): Linear(in_features=256, out_features=256, bias=True)
# )
# SiLU()
# Linear(in_features=256, out_features=256, bias=True)
# Block(
#   (proj): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (norm): GroupNorm(8, 128, eps=1e-05, affine=True)
#   (act): SiLU()
# )
# Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# GroupNorm(8, 128, eps=1e-05, affine=True)
# SiLU()
# Block(
#   (proj): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (norm): GroupNorm(8, 128, eps=1e-05, affine=True)
#   (act): SiLU()
# )
# Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# GroupNorm(8, 128, eps=1e-05, affine=True)
# SiLU()
# Identity()
# ResnetBlock(
#   (mlp): Sequential(
#     (0): SiLU()
#     (1): Linear(in_features=256, out_features=256, bias=True)
#   )
#   (block1): Block(
#     (proj): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (norm): GroupNorm(8, 128, eps=1e-05, affine=True)
#     (act): SiLU()
#   )
#   (block2): Block(
#     (proj): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (norm): GroupNorm(8, 128, eps=1e-05, affine=True)
#     (act): SiLU()
#   )
#   (res_conv): Identity()
# )
# Sequential(
#   (0): SiLU()
#   (1): Linear(in_features=256, out_features=256, bias=True)
# )
# SiLU()
# Linear(in_features=256, out_features=256, bias=True)
# Block(
#   (proj): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (norm): GroupNorm(8, 128, eps=1e-05, affine=True)
#   (act): SiLU()
# )
# Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# GroupNorm(8, 128, eps=1e-05, affine=True)
# SiLU()
# Block(
#   (proj): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (norm): GroupNorm(8, 128, eps=1e-05, affine=True)
#   (act): SiLU()
# )
# Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# GroupNorm(8, 128, eps=1e-05, affine=True)
# SiLU()
# Identity()
# LinearAttention(
#   (norm): RMSNorm()
#   (to_qkv): Conv2d(128, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (to_out): Sequential(
#     (0): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#     (1): RMSNorm()
#   )
# )
# RMSNorm()
# Conv2d(128, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
# Sequential(
#   (0): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#   (1): RMSNorm()
# )
# Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
# RMSNorm()
# Sequential(
#   (0): Rearrange('b c (h p1) (w p2) -> b (c p1 p2) h w', p1=2, p2=2)
#   (1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
# )
# Rearrange('b c (h p1) (w p2) -> b (c p1 p2) h w', p1=2, p2=2)
# Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
# ModuleList(
#   (0-1): 2 x ResnetBlock(
#     (mlp): Sequential(
#       (0): SiLU()
#       (1): Linear(in_features=256, out_features=512, bias=True)
#     )
#     (block1): Block(
#       (proj): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (norm): GroupNorm(8, 256, eps=1e-05, affine=True)
#       (act): SiLU()
#     )
#     (block2): Block(
#       (proj): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (norm): GroupNorm(8, 256, eps=1e-05, affine=True)
#       (act): SiLU()
#     )
#     (res_conv): Identity()
#   )
#   (2): Attention(
#     (norm): RMSNorm()
#     (attend): Attend(
#       (attn_dropout): Dropout(p=0.0, inplace=False)
#     )
#     (to_qkv): Conv2d(256, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (to_out): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1))
#   )
#   (3): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# )
# ResnetBlock(
#   (mlp): Sequential(
#     (0): SiLU()
#     (1): Linear(in_features=256, out_features=512, bias=True)
#   )
#   (block1): Block(
#     (proj): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (norm): GroupNorm(8, 256, eps=1e-05, affine=True)
#     (act): SiLU()
#   )
#   (block2): Block(
#     (proj): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (norm): GroupNorm(8, 256, eps=1e-05, affine=True)
#     (act): SiLU()
#   )
#   (res_conv): Identity()
# )
# Sequential(
#   (0): SiLU()
#   (1): Linear(in_features=256, out_features=512, bias=True)
# )
# SiLU()
# Linear(in_features=256, out_features=512, bias=True)
# Block(
#   (proj): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (norm): GroupNorm(8, 256, eps=1e-05, affine=True)
#   (act): SiLU()
# )
# Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# GroupNorm(8, 256, eps=1e-05, affine=True)
# SiLU()
# Block(
#   (proj): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (norm): GroupNorm(8, 256, eps=1e-05, affine=True)
#   (act): SiLU()
# )
# Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# GroupNorm(8, 256, eps=1e-05, affine=True)
# SiLU()
# Identity()
# ResnetBlock(
#   (mlp): Sequential(
#     (0): SiLU()
#     (1): Linear(in_features=256, out_features=512, bias=True)
#   )
#   (block1): Block(
#     (proj): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (norm): GroupNorm(8, 256, eps=1e-05, affine=True)
#     (act): SiLU()
#   )
#   (block2): Block(
#     (proj): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (norm): GroupNorm(8, 256, eps=1e-05, affine=True)
#     (act): SiLU()
#   )
#   (res_conv): Identity()
# )
# Sequential(
#   (0): SiLU()
#   (1): Linear(in_features=256, out_features=512, bias=True)
# )
# SiLU()
# Linear(in_features=256, out_features=512, bias=True)
# Block(
#   (proj): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (norm): GroupNorm(8, 256, eps=1e-05, affine=True)
#   (act): SiLU()
# )
# Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# GroupNorm(8, 256, eps=1e-05, affine=True)
# SiLU()
# Block(
#   (proj): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (norm): GroupNorm(8, 256, eps=1e-05, affine=True)
#   (act): SiLU()
# )
# Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# GroupNorm(8, 256, eps=1e-05, affine=True)
# SiLU()
# Identity()
# Attention(
#   (norm): RMSNorm()
#   (attend): Attend(
#     (attn_dropout): Dropout(p=0.0, inplace=False)
#   )
#   (to_qkv): Conv2d(256, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (to_out): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1))
# )
# RMSNorm()
# Attend(
#   (attn_dropout): Dropout(p=0.0, inplace=False)
# )
# Dropout(p=0.0, inplace=False)
# Conv2d(256, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
# Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1))
# Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# ModuleList(
#   (0): ModuleList(
#     (0-1): 2 x ResnetBlock(
#       (mlp): Sequential(
#         (0): SiLU()
#         (1): Linear(in_features=256, out_features=1024, bias=True)
#       )
#       (block1): Block(
#         (proj): Conv2d(768, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm): GroupNorm(8, 512, eps=1e-05, affine=True)
#         (act): SiLU()
#       )
#       (block2): Block(
#         (proj): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm): GroupNorm(8, 512, eps=1e-05, affine=True)
#         (act): SiLU()
#       )
#       (res_conv): Conv2d(768, 512, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (2): Attention(
#       (norm): RMSNorm()
#       (attend): Attend(
#         (attn_dropout): Dropout(p=0.0, inplace=False)
#       )
#       (to_qkv): Conv2d(512, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (to_out): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (3): Sequential(
#       (0): Upsample(scale_factor=2.0, mode='nearest')
#       (1): Conv2d(512, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#   )
#   (1): ModuleList(
#     (0-1): 2 x ResnetBlock(
#       (mlp): Sequential(
#         (0): SiLU()
#         (1): Linear(in_features=256, out_features=512, bias=True)
#       )
#       (block1): Block(
#         (proj): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm): GroupNorm(8, 256, eps=1e-05, affine=True)
#         (act): SiLU()
#       )
#       (block2): Block(
#         (proj): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm): GroupNorm(8, 256, eps=1e-05, affine=True)
#         (act): SiLU()
#       )
#       (res_conv): Conv2d(384, 256, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (2): LinearAttention(
#       (norm): RMSNorm()
#       (to_qkv): Conv2d(256, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (to_out): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1))
#         (1): RMSNorm()
#       )
#     )
#     (3): Sequential(
#       (0): Upsample(scale_factor=2.0, mode='nearest')
#       (1): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#   )
#   (2): ModuleList(
#     (0-1): 2 x ResnetBlock(
#       (mlp): Sequential(
#         (0): SiLU()
#         (1): Linear(in_features=256, out_features=256, bias=True)
#       )
#       (block1): Block(
#         (proj): Conv2d(192, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm): GroupNorm(8, 128, eps=1e-05, affine=True)
#         (act): SiLU()
#       )
#       (block2): Block(
#         (proj): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm): GroupNorm(8, 128, eps=1e-05, affine=True)
#         (act): SiLU()
#       )
#       (res_conv): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (2): LinearAttention(
#       (norm): RMSNorm()
#       (to_qkv): Conv2d(128, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (to_out): Sequential(
#         (0): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#         (1): RMSNorm()
#       )
#     )
#     (3): Sequential(
#       (0): Upsample(scale_factor=2.0, mode='nearest')
#       (1): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#   )
#   (3): ModuleList(
#     (0-1): 2 x ResnetBlock(
#       (mlp): Sequential(
#         (0): SiLU()
#         (1): Linear(in_features=256, out_features=128, bias=True)
#       )
#       (block1): Block(
#         (proj): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (act): SiLU()
#       )
#       (block2): Block(
#         (proj): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#         (act): SiLU()
#       )
#       (res_conv): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (2): LinearAttention(
#       (norm): RMSNorm()
#       (to_qkv): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (to_out): Sequential(
#         (0): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#         (1): RMSNorm()
#       )
#     )
#     (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   )
# )
# ModuleList(
#   (0-1): 2 x ResnetBlock(
#     (mlp): Sequential(
#       (0): SiLU()
#       (1): Linear(in_features=256, out_features=1024, bias=True)
#     )
#     (block1): Block(
#       (proj): Conv2d(768, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (norm): GroupNorm(8, 512, eps=1e-05, affine=True)
#       (act): SiLU()
#     )
#     (block2): Block(
#       (proj): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (norm): GroupNorm(8, 512, eps=1e-05, affine=True)
#       (act): SiLU()
#     )
#     (res_conv): Conv2d(768, 512, kernel_size=(1, 1), stride=(1, 1))
#   )
#   (2): Attention(
#     (norm): RMSNorm()
#     (attend): Attend(
#       (attn_dropout): Dropout(p=0.0, inplace=False)
#     )
#     (to_qkv): Conv2d(512, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (to_out): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1))
#   )
#   (3): Sequential(
# ...
#   (2): LinearAttention(
#     (norm): RMSNorm()
#     (to_qkv): Conv2d(256, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (to_out): Sequential(
#       (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1))
#       (1): RMSNorm()
#     )
#   )
#   (3): Sequential(
#     (0): Upsample(scale_factor=2.0, mode='nearest')
#     (1): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   )
# )
# ResnetBlock(
#   (mlp): Sequential(
#     (0): SiLU()
#     (1): Linear(in_features=256, out_features=512, bias=True)
#   )
#   (block1): Block(
#     (proj): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (norm): GroupNorm(8, 256, eps=1e-05, affine=True)
#     (act): SiLU()
#   )
#   (block2): Block(
#     (proj): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (norm): GroupNorm(8, 256, eps=1e-05, affine=True)
#     (act): SiLU()
#   )
#   (res_conv): Conv2d(384, 256, kernel_size=(1, 1), stride=(1, 1))
# )
# Sequential(
#   (0): SiLU()
#   (1): Linear(in_features=256, out_features=512, bias=True)
# )
# SiLU()
# Linear(in_features=256, out_features=512, bias=True)
# Block(
#   (proj): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (norm): GroupNorm(8, 256, eps=1e-05, affine=True)
#   (act): SiLU()
# )
# Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# GroupNorm(8, 256, eps=1e-05, affine=True)
# SiLU()
# Block(
#   (proj): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (norm): GroupNorm(8, 256, eps=1e-05, affine=True)
#   (act): SiLU()
# )
# Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# GroupNorm(8, 256, eps=1e-05, affine=True)
# SiLU()
# Conv2d(384, 256, kernel_size=(1, 1), stride=(1, 1))
# ResnetBlock(
#   (mlp): Sequential(
#     (0): SiLU()
#     (1): Linear(in_features=256, out_features=512, bias=True)
#   )
#   (block1): Block(
#     (proj): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (norm): GroupNorm(8, 256, eps=1e-05, affine=True)
#     (act): SiLU()
#   )
#   (block2): Block(
#     (proj): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (norm): GroupNorm(8, 256, eps=1e-05, affine=True)
#     (act): SiLU()
#   )
#   (res_conv): Conv2d(384, 256, kernel_size=(1, 1), stride=(1, 1))
# )
# Sequential(
#   (0): SiLU()
#   (1): Linear(in_features=256, out_features=512, bias=True)
# )
# SiLU()
# Linear(in_features=256, out_features=512, bias=True)
# Block(
#   (proj): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (norm): GroupNorm(8, 256, eps=1e-05, affine=True)
#   (act): SiLU()
# )
# Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# GroupNorm(8, 256, eps=1e-05, affine=True)
# SiLU()
# Block(
#   (proj): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (norm): GroupNorm(8, 256, eps=1e-05, affine=True)
#   (act): SiLU()
# )
# Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# GroupNorm(8, 256, eps=1e-05, affine=True)
# SiLU()
# Conv2d(384, 256, kernel_size=(1, 1), stride=(1, 1))
# LinearAttention(
#   (norm): RMSNorm()
#   (to_qkv): Conv2d(256, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (to_out): Sequential(
#     (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1))
#     (1): RMSNorm()
#   )
# )
# RMSNorm()
# Conv2d(256, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
# Sequential(
#   (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1))
#   (1): RMSNorm()
# )
# Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1))
# RMSNorm()
# Sequential(
#   (0): Upsample(scale_factor=2.0, mode='nearest')
#   (1): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# )
# Upsample(scale_factor=2.0, mode='nearest')
# Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# ModuleList(
#   (0-1): 2 x ResnetBlock(
#     (mlp): Sequential(
#       (0): SiLU()
#       (1): Linear(in_features=256, out_features=256, bias=True)
#     )
#     (block1): Block(
#       (proj): Conv2d(192, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (norm): GroupNorm(8, 128, eps=1e-05, affine=True)
#       (act): SiLU()
#     )
#     (block2): Block(
#       (proj): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (norm): GroupNorm(8, 128, eps=1e-05, affine=True)
#       (act): SiLU()
#     )
#     (res_conv): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1))
#   )
#   (2): LinearAttention(
#     (norm): RMSNorm()
#     (to_qkv): Conv2d(128, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (to_out): Sequential(
#       (0): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#       (1): RMSNorm()
#     )
#   )
#   (3): Sequential(
#     (0): Upsample(scale_factor=2.0, mode='nearest')
#     (1): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   )
# )
# ResnetBlock(
#   (mlp): Sequential(
#     (0): SiLU()
#     (1): Linear(in_features=256, out_features=256, bias=True)
#   )
#   (block1): Block(
#     (proj): Conv2d(192, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (norm): GroupNorm(8, 128, eps=1e-05, affine=True)
#     (act): SiLU()
#   )
#   (block2): Block(
#     (proj): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (norm): GroupNorm(8, 128, eps=1e-05, affine=True)
#     (act): SiLU()
#   )
#   (res_conv): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1))
# )
# Sequential(
#   (0): SiLU()
#   (1): Linear(in_features=256, out_features=256, bias=True)
# )
# SiLU()
# Linear(in_features=256, out_features=256, bias=True)
# Block(
#   (proj): Conv2d(192, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (norm): GroupNorm(8, 128, eps=1e-05, affine=True)
#   (act): SiLU()
# )
# Conv2d(192, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# GroupNorm(8, 128, eps=1e-05, affine=True)
# SiLU()
# Block(
#   (proj): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (norm): GroupNorm(8, 128, eps=1e-05, affine=True)
#   (act): SiLU()
# )
# Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# GroupNorm(8, 128, eps=1e-05, affine=True)
# SiLU()
# Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1))
# ResnetBlock(
#   (mlp): Sequential(
#     (0): SiLU()
#     (1): Linear(in_features=256, out_features=256, bias=True)
#   )
#   (block1): Block(
#     (proj): Conv2d(192, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (norm): GroupNorm(8, 128, eps=1e-05, affine=True)
#     (act): SiLU()
#   )
#   (block2): Block(
#     (proj): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (norm): GroupNorm(8, 128, eps=1e-05, affine=True)
#     (act): SiLU()
#   )
#   (res_conv): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1))
# )
# Sequential(
#   (0): SiLU()
#   (1): Linear(in_features=256, out_features=256, bias=True)
# )
# SiLU()
# Linear(in_features=256, out_features=256, bias=True)
# Block(
#   (proj): Conv2d(192, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (norm): GroupNorm(8, 128, eps=1e-05, affine=True)
#   (act): SiLU()
# )
# Conv2d(192, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# GroupNorm(8, 128, eps=1e-05, affine=True)
# SiLU()
# Block(
#   (proj): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (norm): GroupNorm(8, 128, eps=1e-05, affine=True)
#   (act): SiLU()
# )
# Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# GroupNorm(8, 128, eps=1e-05, affine=True)
# SiLU()
# Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1))
# LinearAttention(
#   (norm): RMSNorm()
#   (to_qkv): Conv2d(128, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (to_out): Sequential(
#     (0): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#     (1): RMSNorm()
#   )
# )
# RMSNorm()
# Conv2d(128, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
# Sequential(
#   (0): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#   (1): RMSNorm()
# )
# Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
# RMSNorm()
# Sequential(
#   (0): Upsample(scale_factor=2.0, mode='nearest')
#   (1): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# )
# Upsample(scale_factor=2.0, mode='nearest')
# Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# ModuleList(
#   (0-1): 2 x ResnetBlock(
#     (mlp): Sequential(
#       (0): SiLU()
#       (1): Linear(in_features=256, out_features=128, bias=True)
#     )
#     (block1): Block(
#       (proj): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#       (act): SiLU()
#     )
#     (block2): Block(
#       (proj): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#       (act): SiLU()
#     )
#     (res_conv): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#   )
#   (2): LinearAttention(
#     (norm): RMSNorm()
#     (to_qkv): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (to_out): Sequential(
#       (0): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#       (1): RMSNorm()
#     )
#   )
#   (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# )
# ResnetBlock(
#   (mlp): Sequential(
#     (0): SiLU()
#     (1): Linear(in_features=256, out_features=128, bias=True)
#   )
#   (block1): Block(
#     (proj): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#     (act): SiLU()
#   )
#   (block2): Block(
#     (proj): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#     (act): SiLU()
#   )
#   (res_conv): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
# )
# Sequential(
#   (0): SiLU()
#   (1): Linear(in_features=256, out_features=128, bias=True)
# )
# SiLU()
# Linear(in_features=256, out_features=128, bias=True)
# Block(
#   (proj): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#   (act): SiLU()
# )
# Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# GroupNorm(8, 64, eps=1e-05, affine=True)
# SiLU()
# Block(
#   (proj): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#   (act): SiLU()
# )
# Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# GroupNorm(8, 64, eps=1e-05, affine=True)
# SiLU()
# Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
# ResnetBlock(
#   (mlp): Sequential(
#     (0): SiLU()
#     (1): Linear(in_features=256, out_features=128, bias=True)
#   )
#   (block1): Block(
#     (proj): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#     (act): SiLU()
#   )
#   (block2): Block(
#     (proj): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#     (act): SiLU()
#   )
#   (res_conv): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
# )
# Sequential(
#   (0): SiLU()
#   (1): Linear(in_features=256, out_features=128, bias=True)
# )
# SiLU()
# Linear(in_features=256, out_features=128, bias=True)
# Block(
#   (proj): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#   (act): SiLU()
# )
# Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# GroupNorm(8, 64, eps=1e-05, affine=True)
# SiLU()
# Block(
#   (proj): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#   (act): SiLU()
# )
# Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# GroupNorm(8, 64, eps=1e-05, affine=True)
# SiLU()
# Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
# LinearAttention(
#   (norm): RMSNorm()
#   (to_qkv): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (to_out): Sequential(
#     (0): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#     (1): RMSNorm()
#   )
# )
# RMSNorm()
# Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
# Sequential(
#   (0): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#   (1): RMSNorm()
# )
# Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
# RMSNorm()
# Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# ResnetBlock(
#   (mlp): Sequential(
#     (0): SiLU()
#     (1): Linear(in_features=256, out_features=1024, bias=True)
#   )
#   (block1): Block(
#     (proj): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (norm): GroupNorm(8, 512, eps=1e-05, affine=True)
#     (act): SiLU()
#   )
#   (block2): Block(
#     (proj): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (norm): GroupNorm(8, 512, eps=1e-05, affine=True)
#     (act): SiLU()
#   )
#   (res_conv): Identity()
# )
# Sequential(
#   (0): SiLU()
#   (1): Linear(in_features=256, out_features=1024, bias=True)
# )
# SiLU()
# Linear(in_features=256, out_features=1024, bias=True)
# Block(
#   (proj): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (norm): GroupNorm(8, 512, eps=1e-05, affine=True)
#   (act): SiLU()
# )
# Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# GroupNorm(8, 512, eps=1e-05, affine=True)
# SiLU()
# Block(
#   (proj): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (norm): GroupNorm(8, 512, eps=1e-05, affine=True)
#   (act): SiLU()
# )
# Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# GroupNorm(8, 512, eps=1e-05, affine=True)
# SiLU()
# Identity()
# Attention(
#   (norm): RMSNorm()
#   (attend): Attend(
#     (attn_dropout): Dropout(p=0.0, inplace=False)
#   )
#   (to_qkv): Conv2d(512, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (to_out): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1))
# )
# RMSNorm()
# Attend(
#   (attn_dropout): Dropout(p=0.0, inplace=False)
# )
# Dropout(p=0.0, inplace=False)
# Conv2d(512, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
# Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1))
# ResnetBlock(
#   (mlp): Sequential(
#     (0): SiLU()
#     (1): Linear(in_features=256, out_features=1024, bias=True)
#   )
#   (block1): Block(
#     (proj): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (norm): GroupNorm(8, 512, eps=1e-05, affine=True)
#     (act): SiLU()
#   )
#   (block2): Block(
#     (proj): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (norm): GroupNorm(8, 512, eps=1e-05, affine=True)
#     (act): SiLU()
#   )
#   (res_conv): Identity()
# )
# Sequential(
#   (0): SiLU()
#   (1): Linear(in_features=256, out_features=1024, bias=True)
# )
# SiLU()
# Linear(in_features=256, out_features=1024, bias=True)
# Block(
#   (proj): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (norm): GroupNorm(8, 512, eps=1e-05, affine=True)
#   (act): SiLU()
# )
# Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# GroupNorm(8, 512, eps=1e-05, affine=True)
# SiLU()
# Block(
#   (proj): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (norm): GroupNorm(8, 512, eps=1e-05, affine=True)
#   (act): SiLU()
# )
# Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# GroupNorm(8, 512, eps=1e-05, affine=True)
# SiLU()
# Identity()
# ResnetBlock(
#   (mlp): Sequential(
#     (0): SiLU()
#     (1): Linear(in_features=256, out_features=128, bias=True)
#   )
#   (block1): Block(
#     (proj): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#     (act): SiLU()
#   )
#   (block2): Block(
#     (proj): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#     (act): SiLU()
#   )
#   (res_conv): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
# )
# Sequential(
#   (0): SiLU()
#   (1): Linear(in_features=256, out_features=128, bias=True)
# )
# SiLU()
# Linear(in_features=256, out_features=128, bias=True)
# Block(
#   (proj): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#   (act): SiLU()
# )
# Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# GroupNorm(8, 64, eps=1e-05, affine=True)
# SiLU()
# Block(
#   (proj): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (norm): GroupNorm(8, 64, eps=1e-05, affine=True)
#   (act): SiLU()
# )
# Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# GroupNorm(8, 64, eps=1e-05, affine=True)
# SiLU()
# Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
# Conv2d(64, 3, kernel_size=(1, 1), stride=(1, 1))
